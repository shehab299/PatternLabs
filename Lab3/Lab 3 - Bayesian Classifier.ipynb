# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import csv
import math

# %matplotlib qt

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.

def read_data(file_name):
    ## HINT 1: How is the data ordered in the file? 
    ## HINT 2: Do you need to cast the data you read from the file? (yes, data is read as strings)

    reader = csv.reader(open(file_name, "r"), delimiter=",")
    data = []

    for row in reader:
        row = np.array(row).astype(float)
        data.append(row)

    data = np.array(data, dtype=np.float32)

    return data

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data [DONE]
    ## HINT: Do you need to cast the data you read from the file?

    test_data = []
    test_data_true = []

    reader = csv.reader(open("test_data.csv", "r"), delimiter=",")
    for row in reader:
        row = np.array(row).astype(np.float32)
        test_data.append(row)

    test_data = np.array(test_data, dtype=np.float32)
            
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true [DONE]
    ## HINT: Do you need to cast the data you read from the file?

    reader = csv.reader(open("test_data_true.csv", "r"), delimiter=",")
    for row in reader:
        row = np.array(row).astype(np.float32)
        test_data_true.append(row)

    test_data_true = np.array(test_data_true, dtype=np.float32)

    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

numClasses = 3 
M = len(training_data)
N = len(training_data[0]) - 1
K = len(test_data)

X = training_data[:, 1:]
X_Test = test_data
Y = training_data[:, 0]


print("Number of training examples: ", M)
print("Number of features: ", N)
print("Number of test examples: ", K)
# Out:
# Number of training examples:  1150
# Number of features:  2
# Number of test examples:  450

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']

fig = plt.figure()
ax = fig.add_subplot(111)

X_red = X[Y == 1]
X_green = X[Y == 2]
X_blue = X[Y == 3]

ax.scatter(X_red[:, 0], X_red[:, 1], c=colors[0], label='Class 1')
ax.scatter(X_green[:, 0], X_green[:, 1], c=colors[1], label='Class 2')
ax.scatter(X_blue[:, 0], X_blue[:, 1], c=colors[2], label='Class 3')
ax.legend()
ax.set_title("Training Data")

plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:

    1- Data is distributed normally (Gaussian Distribution)
    2- Data is well seperated

'''
# Out:
# '\n    Your Answer:\n\n    1- Data is distributed normally (Gaussian Distribution)\n    2- Data is well seperated\n\n'

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument

for classIndex in range(numClasses):

    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.

    X_class = X[Y == (classIndex + 1)]

    # Rounding to 2 decimal digits after the point to avoid problems in percision
    p = np.round((len(X_class) / len(X)), 2)
    
    pClasses.append(p)
    estimate_means.append(np.mean(X_class, axis = 0))
    estimate_covariances.append(np.cov(X_class, rowvar=False))


estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.sum(pClasses)==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    N = len(mu)
    coeff = 1 / np.sqrt( ((2 * np.pi) ** N) * np.linalg.det(sigma) ) 
    diff = X - mu
    exponent = -0.5 * (diff.T @ np.linalg.inv(sigma) @ diff)
    return coeff * np.exp(exponent)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8, 'Incorrect Gaussian Probability calculated'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.



for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)

    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    classProbabilities[0] = multivariate_normal_gaussian(X_Test[i], estimate_means[0], estimate_covariances[0])
    classProbabilities[1] = multivariate_normal_gaussian(X_Test[i], estimate_means[1], estimate_covariances[1])
    classProbabilities[2] = multivariate_normal_gaussian(X_Test[i], estimate_means[2], estimate_covariances[2])
    
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities) + 1)
    

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.701414   3.8725362]
# Class Probabilities:  [6.11031934e-12 6.16972800e-17 1.14599278e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.818318 -5.009778]
# Class Probabilities:  [3.54332441e-02 4.59232566e-10 8.95190097e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.5707195  9.9603615]
# Class Probabilities:  [1.82498038e-19 3.92600701e-03 2.47809597e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.9430904  -0.01539406]
# Class Probabilities:  [4.50266440e-06 5.58456119e-08 2.61956328e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.2608256  -0.61349356]
# Class Probabilities:  [1.43533938e-05 1.43296068e-07 2.17483458e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.9890114 16.862682 ]
# Class Probabilities:  [1.03214993e-35 8.89198785e-04 7.64823413e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.27964848 -3.3865535 ]
# Class Probabilities:  [5.09801839e-03 3.34971426e-07 3.83563179e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.6050334 -0.2420632]
# Class Probabilities:  [1.95900627e-04 5.60148186e-06 1.03250740e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312624 12.421304  ]
# Class Probabilities:  [1.66270512e-19 1.50015298e-02 7.82653015e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.5225306 10.136689 ]
# Class Probabilities:  [7.21089733e-25 4.03425080e-06 3.43221502e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.5947204 -4.3793836]
# Class Probabilities:  [6.55742191e-09 1.01417016e-11 5.31770335e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.985968   -0.73837507]
# Class Probabilities:  [1.83865085e-03 3.43141872e-06 2.03976905e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.239085 13.213588]
# Class Probabilities:  [1.70606788e-25 9.54041398e-03 1.73718038e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789974 -11.01635  ]
# Class Probabilities:  [2.50415853e-03 4.62076821e-20 9.52995219e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.5954527 -0.4195549]
# Class Probabilities:  [1.31953108e-03 3.07544614e-05 2.10805620e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.361294  -5.4210296]
# Class Probabilities:  [1.13524491e-14 5.20611271e-17 1.09367000e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.5284822 -7.4289355]
# Class Probabilities:  [4.49422659e-03 1.67034862e-11 5.85094243e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.5608606 -9.03279  ]
# Class Probabilities:  [5.97914865e-03 7.65512816e-15 2.29134435e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.0218806 -0.9373527]
# Class Probabilities:  [1.44935746e-08 2.01238414e-11 2.42666557e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.150987  1.4375061]
# Class Probabilities:  [2.07638553e-10 3.21086850e-14 1.00044174e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.7100703 10.679777 ]
# Class Probabilities:  [1.41342939e-18 2.83408509e-02 1.33451527e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.7630243 -5.5529766]
# Class Probabilities:  [3.94649801e-02 1.90782113e-11 1.03580027e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.898834  -5.3949666]
# Class Probabilities:  [3.80307730e-02 1.92082371e-11 9.18159877e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379   2.7159069]
# Class Probabilities:  [7.49548227e-09 1.82096637e-11 1.03511269e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.892157  -2.5946083]
# Class Probabilities:  [5.41114617e-03 4.44584414e-09 4.92735508e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.1183467  4.910662 ]
# Class Probabilities:  [2.40695020e-10 2.42654512e-04 1.63169285e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.457177  -2.4393446]
# Class Probabilities:  [1.16838148e-08 1.72723415e-11 1.67619438e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.5654709 4.9207544]
# Class Probabilities:  [4.78077325e-07 3.16419038e-03 3.91253622e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.2626563 6.5794144]
# Class Probabilities:  [5.20389672e-09 9.97969773e-03 4.66587678e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.7083244 -3.1117442]
# Class Probabilities:  [7.10821978e-05 6.20620580e-08 5.25808155e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.108369 -11.765525]
# Class Probabilities:  [1.87957194e-03 3.21629298e-25 8.60380279e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.8172665 -5.3687787]
# Class Probabilities:  [3.81908325e-02 2.48051421e-11 1.09644070e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975348  9.753431  ]
# Class Probabilities:  [3.97163158e-15 4.17209226e-02 5.71175983e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.5889363 -3.9363103]
# Class Probabilities:  [1.53757011e-03 7.75412430e-14 7.63703878e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.384362 -12.147286]
# Class Probabilities:  [5.43218768e-04 5.21864425e-31 6.80802390e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.1530385 -5.99521  ]
# Class Probabilities:  [2.19008925e-11 7.64348590e-14 1.14757422e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072336 9.72115   ]
# Class Probabilities:  [4.67542754e-14 2.51090887e-02 2.36465030e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.79772  ]
# Class Probabilities:  [3.50250221e-12 1.65664073e-02 1.87638216e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.705011 11.561743]
# Class Probabilities:  [2.84813356e-25 4.17439844e-04 9.34102654e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.1264336 -4.836169 ]
# Class Probabilities:  [2.95656437e-02 2.16403714e-09 3.22660606e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.0567427 12.571559 ]
# Class Probabilities:  [3.28113987e-17 8.57592730e-05 6.80033816e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.301062 -10.60425 ]
# Class Probabilities:  [4.52158184e-04 1.91111602e-16 2.64278021e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.117765   -0.99143916]
# Class Probabilities:  [1.99424122e-06 9.52464583e-09 2.52427704e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.0549335 -5.871898 ]
# Class Probabilities:  [4.39653896e-11 1.34970523e-13 1.32163176e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.7427595 -3.9752753]
# Class Probabilities:  [2.72767596e-06 2.18638843e-09 5.02127266e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.0217023 -5.5724483]
# Class Probabilities:  [3.69723147e-02 9.43909490e-11 3.91308243e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.2781014 -3.9999833]
# Class Probabilities:  [1.66008486e-02 1.24636393e-10 1.19891049e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.8098836 3.436995 ]
# Class Probabilities:  [4.32071982e-07 1.43254218e-07 9.26408432e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.631167  1.7616552]
# Class Probabilities:  [1.19724456e-09 5.27093003e-13 1.19159789e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.737613  -6.1697865]
# Class Probabilities:  [3.95781643e-02 5.24877094e-12 6.08739727e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.284115 -2.284529]
# Class Probabilities:  [3.84506222e-21 7.07890359e-27 1.24021619e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.4777539  -0.10213091]
# Class Probabilities:  [9.83649233e-04 1.62271637e-05 4.43881085e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.427587  -7.1513934]
# Class Probabilities:  [2.65859217e-02 1.13161663e-12 3.70122176e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.7180569 -8.493555 ]
# Class Probabilities:  [3.26022110e-04 2.95840679e-12 4.23131847e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.0705643 13.271068 ]
# Class Probabilities:  [8.00718794e-29 8.49428029e-04 5.50046183e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.8259473 -9.524261 ]
# Class Probabilities:  [3.53032420e-04 5.67311294e-14 1.84027704e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.289359   1.3531982]
# Class Probabilities:  [4.44465001e-12 7.94026182e-17 4.81393769e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.1341928  9.001529 ]
# Class Probabilities:  [1.74651339e-14 3.69178038e-02 7.48328971e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226866  7.9751787 ]
# Class Probabilities:  [6.24638624e-12 3.38322899e-02 1.21921099e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.469979  -1.9929945]
# Class Probabilities:  [5.51903117e-13 9.68425497e-17 6.37556496e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.0541692 -2.474259 ]
# Class Probabilities:  [8.62377263e-03 1.34664038e-06 2.32964280e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.2155323 12.538631 ]
# Class Probabilities:  [1.85494855e-18 3.11845858e-03 2.18418149e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.859538  -0.7651872]
# Class Probabilities:  [4.75577823e-11 1.03530503e-14 1.28182191e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.115604  -2.5152166]
# Class Probabilities:  [5.95878166e-06 1.20158892e-08 1.28556779e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.886336  -7.7399416]
# Class Probabilities:  [3.03918403e-02 5.84585396e-15 1.07261551e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.7993397  5.3132243]
# Class Probabilities:  [5.82939051e-09 6.77311494e-03 5.22988939e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.3427138 16.235296 ]
# Class Probabilities:  [2.33345748e-28 8.00019539e-04 4.54744444e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55914  10.487078]
# Class Probabilities:  [6.05284177e-15 1.27419068e-02 1.05568180e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.861229   7.1590343]
# Class Probabilities:  [7.25504157e-12 1.62247639e-02 4.79408100e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.3879488  4.1855865]
# Class Probabilities:  [1.35127135e-08 4.99993368e-04 1.22979425e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.527273  -7.2120843]
# Class Probabilities:  [3.15488767e-03 1.17736562e-20 3.30772602e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.9895616 -7.5666013]
# Class Probabilities:  [2.68451911e-02 1.08503109e-13 7.89111214e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.754059 -5.301923]
# Class Probabilities:  [1.59877666e-03 3.61215345e-17 1.63442579e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.9462163 -6.885166 ]
# Class Probabilities:  [2.40054652e-02 5.87650931e-12 1.17668677e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.3199444 -2.6304471]
# Class Probabilities:  [3.90671894e-03 1.40768978e-09 2.08774806e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36298  -8.568228]
# Class Probabilities:  [6.65562913e-03 8.41797343e-22 9.37021590e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.8158517 -3.09057  ]
# Class Probabilities:  [1.58365895e-02 1.87629598e-08 2.94223204e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.483849 -2.137827]
# Class Probabilities:  [5.60023143e-17 1.11400381e-21 1.11570725e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.3833756 4.66708  ]
# Class Probabilities:  [1.35909514e-08 1.11091207e-09 3.33405487e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.1981173 -3.2086945]
# Class Probabilities:  [1.91690631e-02 4.38844585e-08 7.88640967e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.736648  -5.6402674]
# Class Probabilities:  [3.98363488e-02 1.68390303e-11 1.00706225e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1613517 8.119095 ]
# Class Probabilities:  [3.20734741e-10 8.88592347e-06 5.37954718e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.931924 -7.903046]
# Class Probabilities:  [2.14058981e-02 5.50764724e-14 5.72170630e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.4466305 -1.1081262]
# Class Probabilities:  [1.21754072e-10 4.40834875e-14 1.47266588e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.412667   -6.0275536]
# Class Probabilities:  [2.39230955e-04 2.09437459e-21 9.15620642e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.554529  -6.985977]
# Class Probabilities:  [5.59428628e-04 1.01614029e-22 2.34129845e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.4111466 ]
# Class Probabilities:  [3.01650333e-03 5.00090832e-08 2.26981231e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.8349934 3.0513492]
# Class Probabilities:  [9.47000742e-08 3.02949705e-09 1.14170148e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284  8.030622 ]
# Class Probabilities:  [4.80047765e-12 3.43717893e-02 1.07877203e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.672625  -3.6363804]
# Class Probabilities:  [2.20756615e-02 4.24430907e-08 1.45043228e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.2383934 15.509047 ]
# Class Probabilities:  [1.53231262e-26 1.66790619e-03 3.54412473e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415465 -9.490839  ]
# Class Probabilities:  [8.60488763e-06 4.00258184e-13 2.57130238e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934475 14.054166  ]
# Class Probabilities:  [3.33739516e-25 1.19091662e-02 2.33883648e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.0812192 9.021186 ]
# Class Probabilities:  [1.05871935e-12 2.10268064e-02 1.01233948e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.545455 13.384704]
# Class Probabilities:  [3.51895484e-28 1.91503968e-03 1.12878711e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.2568502 12.984588 ]
# Class Probabilities:  [1.89335377e-21 1.68925614e-02 1.04324273e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.491179  -2.0911121]
# Class Probabilities:  [2.02855511e-11 8.90560116e-15 1.06571864e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.637761  2.5922089]
# Class Probabilities:  [9.52862529e-11 7.95621691e-15 5.03755292e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.996321  -0.8183129]
# Class Probabilities:  [8.22317920e-10 4.69024935e-13 1.87477617e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066988 12.604962 ]
# Class Probabilities:  [4.07168823e-18 1.16302645e-03 2.94874050e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.997559  ]
# Class Probabilities:  [1.90776670e-24 1.15137576e-02 4.82622211e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622923 -4.143453 ]
# Class Probabilities:  [2.72437582e-02 9.41017402e-09 5.83023484e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.735881  -8.5950365]
# Class Probabilities:  [1.83528896e-02 1.06068094e-15 4.59984684e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.8769193 -8.514653 ]
# Class Probabilities:  [1.28717941e-02 1.35911240e-14 2.74893318e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.304616  -2.4288175]
# Class Probabilities:  [2.15822968e-11 1.22788411e-14 1.00519053e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.9255115  9.389049 ]
# Class Probabilities:  [4.32876628e-16 2.52882621e-02 1.17577528e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.066819 -9.764454]
# Class Probabilities:  [1.05349795e-02 1.14466644e-20 4.28960926e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24411  -8.188311]
# Class Probabilities:  [1.51248570e-02 3.61845726e-19 2.82020911e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.376029  -5.9906945]
# Class Probabilities:  [3.91206199e-02 1.52064506e-12 2.11358232e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.2238677 -4.851354 ]
# Class Probabilities:  [2.84678008e-06 1.12238194e-09 2.07969417e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.5540608 -2.8922403]
# Class Probabilities:  [6.05235373e-04 3.62016311e-07 2.72107045e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.6904917 13.40447  ]
# Class Probabilities:  [6.79205210e-20 9.61820154e-04 3.86986673e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.5357115 10.661873 ]
# Class Probabilities:  [1.28956543e-19 1.45687381e-02 3.72767120e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.9678254 -4.3130527]
# Class Probabilities:  [9.29763642e-07 7.36276039e-10 4.24710506e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.0008144  8.872758 ]
# Class Probabilities:  [3.85287820e-15 2.26577379e-02 2.61970537e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.356967  -3.7742383]
# Class Probabilities:  [1.30754613e-02 1.56099669e-10 1.16455692e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.4881105 -3.1615665]
# Class Probabilities:  [1.04967964e-10 1.17301277e-13 9.33705825e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.0657334 -13.367212 ]
# Class Probabilities:  [1.73410697e-05 3.63775295e-22 3.22396986e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.185114  2.6171303]
# Class Probabilities:  [1.87243911e-06 4.81679656e-07 1.37269291e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.278285  1.3135462]
# Class Probabilities:  [2.54287745e-09 1.67856615e-12 1.56255979e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.7924297 1.6403154]
# Class Probabilities:  [2.13093382e-05 6.05867624e-06 1.37090997e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602676]
# Class Probabilities:  [4.35732917e-10 2.33725956e-02 7.33369656e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.7824492 -9.12198  ]
# Class Probabilities:  [5.26901414e-15 2.00130649e-16 1.62337272e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.6043532 -5.380724 ]
# Class Probabilities:  [4.19654104e-07 1.96036988e-10 1.51252252e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.8552594 -6.3454347]
# Class Probabilities:  [2.94122545e-02 2.41017367e-11 2.47282320e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.086214   1.9348786]
# Class Probabilities:  [1.57865041e-16 3.78393441e-24 2.45018859e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.9770179 -8.262473 ]
# Class Probabilities:  [8.32474869e-03 1.98650813e-13 1.96299394e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769 1.2218575]
# Class Probabilities:  [0.00029842 0.00027001 0.00127193]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.285325 -9.43554 ]
# Class Probabilities:  [7.05999051e-03 1.19233578e-22 3.24187510e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.6642901 11.011895 ]
# Class Probabilities:  [7.50809858e-16 1.03626965e-02 3.99887642e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0896618 -1.6922857]
# Class Probabilities:  [5.65425957e-03 6.84433894e-07 1.55685100e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.3378935 -2.6661944]
# Class Probabilities:  [1.20414193e-08 1.81432338e-11 1.52903177e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.5690123  5.510336 ]
# Class Probabilities:  [1.82760440e-08 1.24085751e-02 2.24967001e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.992861  -4.6807857]
# Class Probabilities:  [6.53292626e-06 2.30287399e-09 2.14970775e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.8002173 11.424375 ]
# Class Probabilities:  [2.18775229e-20 2.37780788e-02 2.38717902e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.1692996 -4.7458596]
# Class Probabilities:  [2.91736209e-04 1.66438120e-08 6.18777243e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.774797  ]
# Class Probabilities:  [4.58939690e-26 6.31413362e-03 8.41139863e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.572479   -6.7392244]
# Class Probabilities:  [6.00234111e-05 5.63570216e-25 1.41841468e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.6047635  4.557735 ]
# Class Probabilities:  [2.08166035e-11 6.00828632e-06 1.15848955e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.914937 -4.932039]
# Class Probabilities:  [3.15106181e-13 9.00241712e-16 2.13510652e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.4028087 -4.972807 ]
# Class Probabilities:  [2.88275600e-02 1.25903149e-11 4.81923363e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.0429704 2.030143 ]
# Class Probabilities:  [6.68198504e-05 1.71090919e-04 4.30127491e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.2112203 -10.700868 ]
# Class Probabilities:  [2.66926250e-03 7.84719073e-19 5.72068299e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.5306463 -8.838927 ]
# Class Probabilities:  [1.39136818e-02 1.02185791e-15 4.87109773e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.300221 11.201974]
# Class Probabilities:  [4.04395826e-15 7.42562008e-04 9.33315529e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678263 11.005399  ]
# Class Probabilities:  [8.14226336e-17 2.77415248e-02 1.28395136e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.237599 2.804215]
# Class Probabilities:  [3.13445789e-07 2.08195347e-08 1.35818615e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883183 -1.8903017]
# Class Probabilities:  [9.42231017e-05 1.44726483e-11 4.23028056e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122705 15.014663  ]
# Class Probabilities:  [8.15845853e-28 6.36123437e-03 1.61576695e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.3464111 -4.86072  ]
# Class Probabilities:  [9.01024256e-03 1.42263698e-08 4.06505735e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.6382203 -5.452965 ]
# Class Probabilities:  [1.38719717e-11 4.43235291e-14 1.88630148e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.548072  1.1991326]
# Class Probabilities:  [1.98144860e-07 1.51222554e-09 2.44354374e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.75952     0.33353442]
# Class Probabilities:  [3.43703348e-15 4.86904611e-21 1.43173783e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.043847  3.31532 ]
# Class Probabilities:  [3.76169506e-11 1.63790818e-15 2.65891228e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.7232208 2.8957329]
# Class Probabilities:  [8.09456282e-06 2.34402221e-05 7.52331473e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.2341204 10.508663 ]
# Class Probabilities:  [8.80398119e-22 1.22721565e-03 2.33525125e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.758129 9.809887]
# Class Probabilities:  [4.83922859e-13 2.52293491e-03 1.01900807e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.7170987  0.05250004]
# Class Probabilities:  [8.93612531e-07 6.41860199e-09 2.86903727e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383   14.462532]
# Class Probabilities:  [4.46767288e-33 2.32499048e-04 1.08958570e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.319805   5.6579304]
# Class Probabilities:  [1.50252342e-11 1.36238898e-15 3.45206817e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.375244  -7.749585]
# Class Probabilities:  [1.41591367e-03 4.02392545e-23 1.63437049e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.6002007 -5.4245358]
# Class Probabilities:  [3.90428175e-02 3.68896776e-11 1.57069893e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.2085052 -0.7309436]
# Class Probabilities:  [8.67543589e-05 1.07575738e-06 1.41266232e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.675119   -0.45766944]
# Class Probabilities:  [1.37789755e-10 3.63975959e-14 1.46564614e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.8424103 -2.0720084]
# Class Probabilities:  [8.82693059e-03 5.25368949e-07 2.11878722e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.028154   0.12504484]
# Class Probabilities:  [3.93379742e-06 5.27542156e-08 2.64756321e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.6352797 10.8219385]
# Class Probabilities:  [1.63760166e-15 1.11105900e-02 5.76348297e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.695464  1.6379328]
# Class Probabilities:  [6.27620248e-06 7.14629099e-07 1.85603052e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.2049584 -8.541825 ]
# Class Probabilities:  [7.58508963e-03 6.07667410e-14 8.92019504e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.8566484  8.271079 ]
# Class Probabilities:  [4.09475681e-19 2.14150579e-05 4.92592593e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.432664  -7.3131533]
# Class Probabilities:  [3.35859430e-02 6.14397236e-14 4.54805995e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.4374378 10.573581 ]
# Class Probabilities:  [5.68724424e-14 6.40901475e-04 3.64693042e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.5169106 1.908959 ]
# Class Probabilities:  [7.19296308e-06 1.48509530e-06 1.60669021e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.9539373 -2.0629   ]
# Class Probabilities:  [8.93412919e-05 2.34871534e-07 9.38173882e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.170227  -4.7191496]
# Class Probabilities:  [1.84975336e-02 9.47809582e-09 1.49431925e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.8794336  0.56763303]
# Class Probabilities:  [7.11722476e-08 2.25295393e-10 2.60867953e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.901554  -2.4944613]
# Class Probabilities:  [1.90560966e-12 7.27199801e-16 7.22890007e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309706 10.133502  ]
# Class Probabilities:  [6.49073210e-15 2.69765133e-02 9.48305228e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.830462 -9.954632]
# Class Probabilities:  [8.48372623e-03 7.95797138e-19 5.53363472e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.480847  2.2169003]
# Class Probabilities:  [2.70284099e-08 1.19672689e-10 1.51917909e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.5148416 16.058565 ]
# Class Probabilities:  [3.39812764e-36 3.63953076e-04 6.36970386e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.297961  -1.5196037]
# Class Probabilities:  [5.88338392e-03 2.47173844e-06 5.49709700e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.0467508 14.393254 ]
# Class Probabilities:  [6.45447353e-24 4.53966575e-03 6.65556456e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.332237  -7.6324134]
# Class Probabilities:  [8.60945949e-03 3.11562177e-12 1.32293065e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.3894496 -9.233252 ]
# Class Probabilities:  [4.01004582e-03 6.70346956e-15 2.28653569e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.741764  -5.0251293]
# Class Probabilities:  [3.54391069e-02 6.12458922e-11 1.67460151e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.4100466 -5.5997005]
# Class Probabilities:  [1.08670565e-02 4.81552373e-15 3.60792204e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.097973 -7.512829]
# Class Probabilities:  [1.53285212e-02 3.64771381e-18 9.51450176e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055  14.732665]
# Class Probabilities:  [4.83540846e-24 1.91339286e-03 4.82658887e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.1521902 3.6387303]
# Class Probabilities:  [6.37890427e-06 1.82887880e-03 8.06536350e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.255433  9.241322]
# Class Probabilities:  [4.56285123e-15 3.61968916e-02 4.13264343e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701863 10.616883 ]
# Class Probabilities:  [2.73806478e-19 1.72073783e-02 5.37264793e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.263297   -7.9234447]
# Class Probabilities:  [3.93180162e-04 1.82724120e-25 9.57349269e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.375985  5.7652965]
# Class Probabilities:  [5.46626375e-08 6.17965267e-03 1.37198155e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.881407  -3.0240297]
# Class Probabilities:  [1.47240951e-02 1.86726412e-08 2.70112384e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.668861  -1.9485708]
# Class Probabilities:  [5.75258536e-03 1.75252228e-07 5.58479838e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.225113  ]
# Class Probabilities:  [1.49560140e-15 3.57062530e-02 4.37991583e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.0173445 -3.0163376]
# Class Probabilities:  [4.14460399e-05 4.47715425e-08 6.50697896e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.4524205 2.1872554]
# Class Probabilities:  [4.46205919e-05 1.15904664e-04 5.34721333e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8133836 -3.048103 ]
# Class Probabilities:  [6.08580255e-05 5.89107233e-08 5.75604054e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.3522625  7.9414535]
# Class Probabilities:  [9.39002915e-13 2.79481884e-02 3.15947939e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3247912 -9.127577 ]
# Class Probabilities:  [3.11912596e-04 3.13240151e-13 7.15725713e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.990323  -0.4646652]
# Class Probabilities:  [2.09117634e-14 1.98361637e-19 2.89097562e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.525573  -5.0005174]
# Class Probabilities:  [5.77667336e-03 1.12733250e-14 4.44274475e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.317395  -7.0891776]
# Class Probabilities:  [3.54652505e-02 1.43782109e-13 7.43478617e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.8748424  6.362561 ]
# Class Probabilities:  [1.77711371e-11 4.21055259e-03 2.79865000e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.700554 17.815086]
# Class Probabilities:  [3.08437042e-38 3.97032714e-04 5.36174963e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.8391364 -3.9236233]
# Class Probabilities:  [2.62671953e-02 3.82345347e-09 1.83508161e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.317857 -8.220127]
# Class Probabilities:  [2.04079720e-02 9.04916993e-15 1.78386040e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.4122047  -0.78866094]
# Class Probabilities:  [1.00448657e-05 7.87929360e-08 2.23484767e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.8652186 -3.8380156]
# Class Probabilities:  [7.56940563e-09 1.17920543e-11 7.92465650e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.2797518 -5.406857 ]
# Class Probabilities:  [1.60857132e-02 2.06039437e-09 7.26293298e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.442524   5.0483656]
# Class Probabilities:  [1.33467491e-11 5.22313937e-16 5.61072971e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.104545 -8.599236]
# Class Probabilities:  [1.36871118e-02 6.10228845e-15 1.58385704e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.79291314 9.94727   ]
# Class Probabilities:  [1.54995056e-14 2.65422150e-02 1.41228090e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.5430465 -2.9251611]
# Class Probabilities:  [4.15108016e-09 5.89655728e-12 1.31110476e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.39028132 12.457582  ]
# Class Probabilities:  [4.47070591e-20 1.97363544e-02 4.33996313e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.432843  1.6318837]
# Class Probabilities:  [9.95722423e-11 9.55276369e-15 8.08065807e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.0956978 1.681194 ]
# Class Probabilities:  [0.00014551 0.00030064 0.00227462]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.8599453 -1.6740468]
# Class Probabilities:  [3.88216463e-10 2.56010403e-13 1.60877931e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.727534   1.0240291]
# Class Probabilities:  [6.16138446e-13 4.88049519e-18 3.59048679e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.3685796 2.7790854]
# Class Probabilities:  [2.25511257e-05 2.29239598e-04 3.73844834e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.46359  -4.880429]
# Class Probabilities:  [3.45457549e-14 9.28705285e-17 1.74474397e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.659121 -3.386283]
# Class Probabilities:  [1.08780404e-04 2.73828873e-15 6.81870666e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.491624   0.68401164]
# Class Probabilities:  [8.59327673e-10 3.27806612e-13 1.58853240e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.094174 -10.833732]
# Class Probabilities:  [2.68765174e-03 3.84159793e-26 3.48607227e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.749071  -1.5747014]
# Class Probabilities:  [3.08383775e-06 1.11167062e-08 2.09265042e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.8396735 -4.486444 ]
# Class Probabilities:  [1.69285638e-02 9.86998159e-12 2.79805536e-08]
# Predicted class is : 1
# ...
# For test point: [5.4154944 1.3073413]
# Class Probabilities:  [2.03131871e-06 6.80864563e-08 2.33820069e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.366823  -2.9402592]
# Class Probabilities:  [1.30189246e-15 2.07313963e-19 2.07921616e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.176866  -0.6761711]
# Class Probabilities:  [1.74618757e-11 2.52863732e-15 1.08912430e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.5603201 10.892489 ]
# Class Probabilities:  [5.30988372e-15 3.05340278e-03 1.07252709e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.8138255 6.3426886]
# Class Probabilities:  [6.96134695e-09 1.27509232e-02 4.06277794e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.580268  9.2914  ]
# Class Probabilities:  [1.65058044e-15 3.12677954e-02 2.36160149e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.858602  -1.0059668]
# Class Probabilities:  [3.32314497e-11 7.56808021e-15 1.22763922e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8165233 -2.7342708]
# Class Probabilities:  [7.67971101e-05 9.92874364e-08 6.70430167e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.91081685 -2.7698421 ]
# Class Probabilities:  [8.54529963e-03 8.64499617e-07 2.47847801e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.0681553  9.532926 ]
# Class Probabilities:  [3.23711565e-19 1.65226865e-03 2.19459332e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.340798 3.069789]
# Class Probabilities:  [3.42502503e-08 4.36810900e-10 1.03995518e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.6403205 12.006845 ]
# Class Probabilities:  [1.49624345e-21 2.25344094e-02 8.23064202e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.021419   -0.12519999]
# Class Probabilities:  [3.39540007e-14 2.49331839e-19 2.90478639e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.8366015 7.6374154]
# Class Probabilities:  [7.14613755e-10 1.80454747e-03 3.85754454e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.5525339 -2.868894 ]
# Class Probabilities:  [2.31631421e-03 7.20083926e-07 1.16121341e-03]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.9716685 -3.2248147]
# Class Probabilities:  [3.98303032e-06 5.08063770e-09 8.66824865e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.9849098 -4.8474956]
# Class Probabilities:  [2.80087369e-02 2.61886533e-09 4.00143885e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.105887  1.5850751]
# Class Probabilities:  [2.65446323e-10 4.63261833e-14 9.87770424e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945  -3.953132]
# Class Probabilities:  [9.00594655e-08 1.18535633e-10 6.96488430e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.7188324 15.153723 ]
# Class Probabilities:  [5.10000298e-25 1.28776407e-03 1.58359981e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163345  9.722885  ]
# Class Probabilities:  [4.33702534e-15 4.18268817e-02 5.88392673e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.042968   1.2511338]
# Class Probabilities:  [2.50274705e-13 9.86541208e-19 2.62496205e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009128  9.653869  ]
# Class Probabilities:  [7.46008979e-15 4.11899319e-02 7.68548167e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.7087607  2.175948 ]
# Class Probabilities:  [2.80570393e-05 5.23465192e-04 7.04725188e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.510452  7.5667396]
# Class Probabilities:  [1.36233210e-09 4.83450222e-05 9.94718103e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.2982548 13.663421 ]
# Class Probabilities:  [3.13124817e-25 1.32929636e-02 2.37127233e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.728646 -6.012116]
# Class Probabilities:  [7.86852002e-04 7.41310899e-20 6.47369723e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899943 17.987484  ]
# Class Probabilities:  [1.72675012e-36 4.04808975e-04 1.81196134e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.7733768  7.241723 ]
# Class Probabilities:  [4.20549499e-11 2.69612996e-02 1.96473867e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.0500777 15.121579 ]
# Class Probabilities:  [1.67191431e-30 3.63668851e-03 1.36477319e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.7935183 -4.316932 ]
# Class Probabilities:  [3.07607074e-02 1.94341237e-09 1.54945556e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.2398705  0.84895897]
# Class Probabilities:  [3.27441788e-08 7.83461305e-11 2.35156878e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.3059645 -3.2315657]
# Class Probabilities:  [8.30754525e-04 8.70480344e-13 2.12415881e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.2822766 -5.2962823]
# Class Probabilities:  [3.42337203e-02 8.83662433e-12 4.73190089e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84285  -4.657769]
# Class Probabilities:  [8.77630369e-13 2.02757711e-15 2.80186803e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.3623145 14.653396 ]
# Class Probabilities:  [1.08421542e-29 3.90326344e-03 3.07144260e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518  -5.996087]
# Class Probabilities:  [4.02099293e-02 3.00843738e-12 3.51137993e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.612373  4.4800973]
# Class Probabilities:  [1.38642335e-09 4.73886445e-12 2.65422941e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.9545718 -2.6426556]
# Class Probabilities:  [1.50343993e-03 8.65439440e-07 1.85112449e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.9114904 -9.430013 ]
# Class Probabilities:  [9.75410458e-03 6.92297583e-17 9.16011103e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90521    5.6689982]
# Class Probabilities:  [8.97170433e-14 5.73086994e-06 1.80314822e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.8238196  9.486992 ]
# Class Probabilities:  [2.85255970e-20 3.55312041e-04 5.28996537e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.514815  -2.6962936]
# Class Probabilities:  [1.92482903e-05 3.12749815e-08 9.53938986e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.818504  -1.4251057]
# Class Probabilities:  [2.93893856e-06 1.15479504e-08 2.20226766e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.323698  -7.1393456]
# Class Probabilities:  [1.31249355e-02 1.02175127e-11 2.46521770e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.4686146 -1.4433357]
# Class Probabilities:  [5.55221894e-04 6.92351207e-09 2.02854921e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.9874036 -5.577164 ]
# Class Probabilities:  [1.15275229e-02 1.95240698e-09 9.40289482e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.650099   4.9348025]
# Class Probabilities:  [4.00314342e-13 3.80509528e-19 2.19599777e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.297999 -4.999797]
# Class Probabilities:  [3.03752010e-02 1.57988105e-11 5.81827585e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.392104 -8.949484]
# Class Probabilities:  [1.29992401e-02 2.62724359e-20 6.74454854e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.7871634 ]
# Class Probabilities:  [3.60729441e-03 4.84782006e-06 1.00302400e-03]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.246584  -0.9064321]
# Class Probabilities:  [7.69545255e-09 8.88066369e-12 2.32296033e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.5600493 -1.0275762]
# Class Probabilities:  [4.57526733e-05 3.66735510e-07 1.60432762e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.3626432  -0.22355351]
# Class Probabilities:  [1.09571525e-08 1.36705971e-11 2.42597609e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.8746824  1.6885141]
# Class Probabilities:  [7.03087347e-06 1.92360361e-05 2.69805996e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.7127154 -9.479908 ]
# Class Probabilities:  [5.36334515e-05 2.34323680e-13 9.27077536e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.7967305 -6.3397956]
# Class Probabilities:  [2.55515182e-02 8.47572941e-15 7.42776297e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311   ]
# Class Probabilities:  [3.29666438e-15 3.83312355e-02 5.91788355e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.827461  -3.5634513]
# Class Probabilities:  [1.50463217e-02 8.97922256e-10 3.68751989e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.9063244 -9.218958 ]
# Class Probabilities:  [1.42919200e-02 9.86452628e-20 1.48822226e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.3687434 0.625456 ]
# Class Probabilities:  [2.05868721e-08 3.67219400e-11 2.35220353e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.225522   -0.20662172]
# Class Probabilities:  [8.17133872e-10 3.79514777e-13 1.82784510e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.2085054 -2.8240316]
# Class Probabilities:  [1.02357448e-03 5.38980768e-07 2.12803577e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.2157974 2.9484005]
# Class Probabilities:  [1.13292180e-05 6.70710218e-05 5.69334593e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.207293 -5.447713]
# Class Probabilities:  [1.49080467e-02 2.04780155e-09 7.76820516e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.400364 -5.321749]
# Class Probabilities:  [3.33284536e-02 6.08487728e-12 3.66217440e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.1215563 ]
# Class Probabilities:  [2.34105240e-03 8.46915870e-08 3.88411601e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.223822 5.713603]
# Class Probabilities:  [1.80893495e-10 4.57424975e-13 6.43829304e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.6395204 -4.657863 ]
# Class Probabilities:  [4.67460821e-03 2.90610140e-08 1.12007314e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705  1.299906]
# Class Probabilities:  [1.83004810e-10 2.71327197e-14 1.02889235e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.959442   1.3443757]
# Class Probabilities:  [3.85418580e-13 1.76555286e-18 2.77728894e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.701387  4.841707]
# Class Probabilities:  [1.18619916e-14 3.83328047e-22 7.75585620e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.134124 8.882379]
# Class Probabilities:  [1.07535405e-11 1.53380988e-10 1.52405389e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.0241668 11.642334 ]
# Class Probabilities:  [3.30090115e-21 1.94114803e-02 1.03813306e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.0690831 1.272935 ]
# Class Probabilities:  [0.00023847 0.00019508 0.00255075]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.662366  -2.5113018]
# Class Probabilities:  [8.17121095e-14 1.68186502e-17 4.45949673e-03]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.

predicted_classes = np.reshape(np.array(predicted_classes), (-1, 1))
accuracy = np.sum(predicted_classes == test_data_true) / len(test_data)


print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.

def predict(x):
    p1 = multivariate_normal_gaussian(x, estimate_means[0], estimate_covariances[0])
    p2 = multivariate_normal_gaussian(x, estimate_means[1], estimate_covariances[1])
    p3 = multivariate_normal_gaussian(x, estimate_means[2], estimate_covariances[2])
    return max(max(p1, p2), p3)


x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)


for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        Z[i, j] = predict([X[i,j], Y[i,j]])

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.add_subplot(111 ,projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
'''
